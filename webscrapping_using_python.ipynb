# %% [markdown]
# <a href="https://colab.research.google.com/github/aliya-fatma011/Machine-Learning/blob/main/webscrapping_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get('https://www.wscubetech.com')

# %%
print(web)
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="viewport" content="initial-scale=1.0, width=device-width"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="stylesheet" href="/_next/static/css/0bb41860bda823af.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/628779d13563f190.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/8c828a84c6cba25d.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/8cb7b7335a3a053c.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-fa015d29d561362e.js"/><script src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js" async=""></script><script src="/_next/static/chunks/7023-7d602368a0a381e0.js" async=""></script><script src="/_next/static/chunks/main-app-55bbd77d
# ...

# %%
web.url
# Out:
# 'https://www.wscubetech.com/'

# %%
web.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/8c828a84c6cba25d.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-fa015d29d561362e.js" rel="preload"/>
#   <script async="" src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js">
#   </script>
# ...

# %%
soup.title
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p
# Out:
# <p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
soup.a
# Out:
# <a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="139"/></span></a>

# %%
soup.h2
# Out:
# <h2 class="fs-18 lh-24 fw-400 text-color-1 mb-16">Online Programs</h2>

# %% [markdown]
# #parsing the html in web page using html

# %% [markdown]
# kinds of objects
# 1.tag
# 2.navigate string
# 3.beautifulsoup
# 4.comments

# %% [markdown]
# #tag

# %%
tag=soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag=soup.p
print(tag)
# Out:
# <p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
tag=soup.h2
print(tag)
# Out:
# <h2 class="fs-18 lh-24 fw-400 text-color-1 mb-16">Online Programs</h2>

# %% [markdown]
# #navigable string

# %%
tag=soup.p.string

# %%
tag
# Out:
# 'Elevate Your Learning Journey with Cutting-Edge Education Technology.'

# %%
tag=soup.h2.string

# %%
tag
# Out:
# 'Online Programs'

# %% [markdown]
# #beautifulsoup

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.head
# Out:
# <head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="initial-scale=1.0, width=device-width" name="viewport"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8c828a84c6cba25d.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-fa015d29d561362e.js" rel="preload"/><script async="" src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js"></script><script async="" src="/_next/static/chunks/7023-7d602368a0a381e0.js"></script><script async="" src="/_next/static/chunks/main-app-55bbd77d79f9187f.js"></script><s
# ...

# %%
soup.find("h3")
# Out:
# <h3 class="fs-18 lh-24 fw-400 mb-16 text-color-1">On-Campus Programs</h3>

# %%
soup.find_all("h3")
# Out:
# [<h3 class="fs-18 lh-24 fw-400 mb-16 text-color-1">On-Campus Programs</h3>]

# %%
soup.find("p")
# Out:
# <p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
soup.find_all("p")
# Out:
# [<p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>]

# %% [markdown]
# #comments

# %%
com=soup.p.string
com
# Out:
# 'Elevate Your Learning Journey with Cutting-Edge Education Technology.'

# %%
soup.p.prettify
# Out:
# <bound method Tag.prettify of <p class="text-color-19 fs-12 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>>

# %%
print(soup.body.prettify)
# Out:
# <bound method Tag.prettify of <body><noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-52JC74P" style="display:none;visibility:hidden" width="0"></iframe>
# ...

# %% [markdown]
# #find elements in web page using python

# %% [markdown]
# 1.finding elements by class

# %% [markdown]
# 2.finding element by Id

# %%
class_data=soup.find("div")
class_data
# Out:
# <div class="Toastify"></div>

# %%
class_data.find_all("p")
# Out:
# []

# %% [markdown]
# extracting diff url

# %%
soup.find_all("a")
# Out:
# [<a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="139"/></span></a>,
#  <a class="nav-items-link cursor-pointer" href="/events"><div class="nav-items-link cursor-pointer"><span class="text-color-2 fs-xl-16 fs-14 fw-400 lh-24 d-block py-lg-16 px-2xl-20 px-lg-16 px-8 apply-as-mentor-btn">Masterclass</span></div></a>,
#  <a class="nav-items-link cursor-pointer" href="/resources"><div class="nav-items-link cursor-pointer"><span class="text-color-2 fs-xl-16 fs-14 fw-400 lh-24 d-block py-lg-16 px-2xl-20 px-lg-16 px-8 apply-as-mentor-btn">Free Resources</span></div></a>,
# ...

# %%
for i in soup.find_all('a'):
 print(i.get('href'))
# Out:
# /
# /events
# /resources
# /alumni
# /
# /about
# /events
# /resources
# /alumni
# /contact
# /
# /
# https://twitter.com/wscubetechindia
# https://www.instagram.com/wscubetechindia/
# https://in.linkedin.com/company/wscubetechindia
# https://www.youtube.com/c/wscubetechjodhpur
# https://www.facebook.com/wscubetech.india
# /contact
# /about
# https://www.wscubetech.com/blog/
# https://courses.wscubetech.com/
# /events
# /marketing
# /data-analytics-course
# /web-development
# /cyber-security
# /mobile-app-development-course
# /privacy-policy
# /terms-and-conditions
# /refund-and-cancellation
# /faq
# https://twitter.com/wscubetechindia
# https://www.instagram.com/wscubetechindia/
# https://in.linkedin.com/company/wscubetechindia
# https://www.youtube.com/c/wscubetechjodhpur
# https://www.facebook.com/wscubetech.india
# /digital-marketing-course
# /data-analytics-course
# /full-stack-developer-course
# /performance-marketing-course
# /seo-course
# /ethical-hacking-course
# ...

# %% [markdown]
# extracting image info in webpage using python

# %%
img=soup.find_all("img")

# %%
img
# Out:
# [<img alt="header-logo" class="max-w-xl-139 max-w-80" data-nimg="1" decoding="async" height="56" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="139"/>,
#  <img alt="logo" data-nimg="1" decoding="async" height="52" loading="lazy" src="/images/ws-cube-white-logo.svg" style="color:transparent" width="106"/>,
#  <img alt="menu" data-nimg="1" decoding="async" height="16" loading="lazy" src="https://deen3evddmddt.cloudfront.net/images/mobile-menu-icon.svg" style="color:transparent" width="16"/>,
#  <img alt="header-logo" class="max-w-xl-139 max-w-90" data-nimg="1" decoding="async" height="40" loading="lazy" src="/images/wscube-tech-logo-2.svg" style="color:transparent" width="90"/>,
#  <img alt="footer-logo" data-nimg="1" decoding="async" height="72" loading="lazy" src="https://deen3evddmddt.cloudfront.net/images/ws-cube-white-logo.svg" style="color:transparent" width="180"/>]

# %%
for i in img:
  print(i.get('src'))
  print(type(i.get("src")))
# Out:
#  /images/ws-cube-white-logo.svg
# <class 'str'>
# /images/ws-cube-white-logo.svg
# <class 'str'>
# https://deen3evddmddt.cloudfront.net/images/mobile-menu-icon.svg
# <class 'str'>
# /images/wscube-tech-logo-2.svg
# <class 'str'>
# https://deen3evddmddt.cloudfront.net/images/ws-cube-white-logo.svg
# <class 'str'>
